# %%
import os
from PIL import Image
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
'''# Corsican dataset paths
images_path = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/corsican/images"
masks_path = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/corsican/masks"

# path to save models, history and results
SAVE_DIR = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/corsican/corsican_model"
os.makedirs(SAVE_DIR, exist_ok=True)'''

# %%
# Kaggle dataset paths
images_path = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/kaggle/images"
masks_path = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/kaggle/masks"

# path to save models, history and results
SAVE_DIR = "/mnt/c/Users/lloyd/OneDrive/Documents/UP/8vo_Semestre/ML_II/kaggle/kaggle_models"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
class FireDataset(Dataset):
    def __init__(self, images_path, masks_path, transform=None):
        self.images_path = images_path
        self.masks_path = masks_path
        self.transform = transform

        self.images = sorted(os.listdir(images_path))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
      img_name = self.images[idx]

      img_path = os.path.join(self.images_path, img_name)
      mask_name = img_name.replace("_rgb", "_gt")
      mask_path = os.path.join(self.masks_path, mask_name)

      image = np.array(Image.open(img_path).convert("RGB"))
      mask = np.array(Image.open(mask_path).convert("L"))

      mask = (mask > 0).astype("float32")

      if self.transform:
          augmented = self.transform(image=image, mask=mask)
          image = augmented["image"]
          mask = augmented["mask"].unsqueeze(0)

      if image.shape[1] != 256 or image.shape[2] != 256:
          image = torch.nn.functional.interpolate(
              image.unsqueeze(0), size=(256, 256), mode="bilinear", align_corners=False
          ).squeeze(0)

      if mask.shape[1] != 256 or mask.shape[2] != 256:
          mask = torch.nn.functional.interpolate(
              mask.unsqueeze(0), size=(256, 256), mode="nearest"
          ).squeeze(0)

      return image, mask

# %%
#Data augmenattion
train_transform  = A.Compose([
    A.HorizontalFlip(p=0.5),            # random flip
    A.VerticalFlip(p=0.5),
    A.Resize(256, 256),                 # resize
    A.HueSaturationValue(p=0.3),
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(256, 256),
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

test_transform = val_transform

# %%
# !pip install segmentation-models-pytorch -q

# %%
#loss function
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, preds, targets):
        preds = torch.sigmoid(preds)

        preds = preds.view(-1)
        targets = targets.view(-1)

        intersection = (preds * targets).sum()
        dice = (2. * intersection + self.smooth) / (
            preds.sum() + targets.sum() + self.smooth
        )

        return 1 - dice

# %%
from torch.utils.data import Subset
import random

def create_data_splits(images_path, masks_path, train_transform, val_transform, data_percentage=1.0):
    """
    Create train/val/test splits using a percentage of the full dataset.
    Args:
        data_percentage: 0.25, 0.50 or 1.0
    Returns:
        train_dataset, val_dataset, test_dataset
    """
    total_size = len(FireDataset(images_path, masks_path))
    used_size  = int(total_size * data_percentage)

    train_size = int(0.70 * used_size)
    val_size   = int(0.15 * used_size)
    test_size  = used_size - train_size - val_size

    print(f'\nUsing {data_percentage*100:.0f}% of dataset:')
    print(f'  Total images : {total_size}')
    print(f'  Used images  : {used_size}')
    print(f'  Train        : {train_size}')
    print(f'  Val          : {val_size}')
    print(f'  Test         : {test_size}')

    full_train = FireDataset(images_path, masks_path, transform=train_transform)
    full_val   = FireDataset(images_path, masks_path, transform=val_transform)
    full_test  = FireDataset(images_path, masks_path, transform=val_transform)

    indices = list(range(total_size))
    random.seed(42)
    random.shuffle(indices)
    indices = indices[:used_size]

    train_idx = indices[:train_size]
    val_idx   = indices[train_size:train_size + val_size]
    test_idx  = indices[train_size + val_size:]

    train_dataset = Subset(full_train, train_idx)
    val_dataset   = Subset(full_val,   val_idx)
    test_dataset  = Subset(full_test,  test_idx)

    return train_dataset, val_dataset, test_dataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

torch.manual_seed(42)
import numpy as np
np.random.seed(42)
random.seed(42)
# Out:
# Using device: cuda

# %%
def get_metrics(preds, targets, threshold=0.5):
    preds = torch.sigmoid(preds)
    preds = (preds > threshold).float()

    preds = preds.view(-1)
    targets = targets.view(-1)

    TP = (preds * targets).sum()
    TN = ((1 - preds) * (1 - targets)).sum()
    FP = (preds * (1 - targets)).sum()
    FN = ((1 - preds) * targets).sum()

    # F1 Score
    precision = TP / (TP + FP + 1e-8)
    recall = TP / (TP + FN + 1e-8)
    f1 = (2 * precision * recall) / (precision + recall + 1e-8)

    # mIoU
    miou = TP / (TP + FP + FN + 1e-8)

    # MCC
    mcc = (TP * TN - FP * FN) / torch.sqrt(
        (TP + FP) * (TP + FN) * (TN + FP) * (TN + FN) + 1e-8
    )

    # HAF (igual a IoU en binario, pero lo dejamos explícito)
    haf = TP / (TP + FP + FN + 1e-8)

    return f1.item(), miou.item(), mcc.item(), haf.item()

# %%
class EarlyStopping:
    """
    Stops training when val_loss does not improve for `patience` consecutive epochs.
    Also saves the best model weights.
    """
    def __init__(self, patience=10, min_delta=1e-4, verbose=True):
        """
        Args:
            patience  : epochs to wait without improvement before stopping
            min_delta : minimum change to count as an improvement
            verbose   : print a message each time the counter increases
        """
        self.patience   = patience
        self.min_delta  = min_delta
        self.verbose    = verbose
        self.counter    = 0
        self.best_loss  = None
        self.best_weights = None
        self.stop       = False

    def __call__(self, val_loss, model):
        if self.best_loss is None or val_loss < self.best_loss - self.min_delta:
            # Improvement found
            self.best_loss    = val_loss
            self.best_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            self.counter      = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"  EarlyStopping: no improvement for {self.counter}/{self.patience} epochs "
                      f"(best val_loss={self.best_loss:.4f})")
            if self.counter >= self.patience:
                self.stop = True

    def restore_best_weights(self, model):
        """Load the best weights back into the model."""
        model.load_state_dict(self.best_weights)
        print(f"  Best weights restored (val_loss={self.best_loss:.4f})")

# %%
import segmentation_models_pytorch as smp
import json as _json

BATCH_SIZE = 8
NUM_EPOCHS = 50

def train_model(train_loader, val_loader, test_loader, data_percentage, num_epochs=50):
    pct_tag      = int(data_percentage * 100)
    pct_str      = f'{pct_tag}%'
    model_path   = os.path.join(SAVE_DIR, f'deeplabv3plus_{pct_tag}.pth')
    history_path = os.path.join(SAVE_DIR, f'deeplabv3plus_history_{pct_tag}.json')
    results_path = os.path.join(SAVE_DIR, f'deeplabv3plus_results_{pct_tag}.json')

    # if the model already exists, load and skip training
    if os.path.exists(model_path) and os.path.exists(history_path) and os.path.exists(results_path):
        print(f'\n{"="*70}')
        print(f'Model {pct_str} already trained. Loading model...')
        print(f'{"="*70}\n')

        model = smp.DeepLabV3Plus(
            encoder_name='resnet50',
            encoder_weights='imagenet',
            in_channels=3,
            classes=1,
            activation=None
        ).to(device)

        checkpoint = torch.load(model_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.eval()

        with open(history_path) as f:
            history = _json.load(f)
        with open(results_path) as f:
            test_results = _json.load(f)

        print(f"  Val mIoU saved : {checkpoint['val_miou']:.4f}")
        print(f"  Test mIoU saved: {test_results['test_miou']:.4f}")
        return history, test_results, model

    # ── Entrenamiento ──
    print(f'\n{"="*70}')
    print(f'TRAINING DeepLabV3+ (ResNet50) WITH {pct_str} OF DATASET')
    print(f'{"="*70}\n')

    model = smp.DeepLabV3Plus(
        encoder_name='resnet50',
        encoder_weights='imagenet',
        in_channels=3,
        classes=1,
        activation=None
    ).to(device)

    criterion      = DiceLoss()
    optimizer      = torch.optim.Adam(model.parameters(), lr=1e-4)
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4, verbose=True)

    best_val_miou = 0.0
    history = {'train_loss':[], 'val_loss':[], 'train_f1':[], 'val_f1':[],
               'train_miou':[], 'val_miou':[], 'train_mcc':[], 'val_mcc':[]}

    for epoch in range(num_epochs):
        # --- TRAIN ---
        model.train()
        train_loss, train_metrics = 0, [0]*4
        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            loss = criterion(outputs, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            metrics = get_metrics(outputs, masks)
            train_metrics = [x + y for x, y in zip(train_metrics, metrics)]
        train_loss /= len(train_loader)
        train_metrics = [x / len(train_loader) for x in train_metrics]

        # --- VALIDATION ---
        model.eval()
        val_loss, val_metrics = 0, [0]*4
        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                loss = criterion(outputs, masks)
                val_loss += loss.item()
                metrics = get_metrics(outputs, masks)
                val_metrics = [x + y for x, y in zip(val_metrics, metrics)]
        val_loss /= len(val_loader)
        val_metrics = [x / len(val_loader) for x in val_metrics]

        # --- LOG ---
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_f1'].append(train_metrics[0])
        history['val_f1'].append(val_metrics[0])
        history['train_miou'].append(train_metrics[1])
        history['val_miou'].append(val_metrics[1])
        history['train_mcc'].append(train_metrics[2])
        history['val_mcc'].append(val_metrics[2])

        # --- BES MODEL SAVED ---
        val_miou = val_metrics[1]
        if val_miou > best_val_miou:
            best_val_miou = val_miou
            torch.save({'epoch': epoch,
                        'model_state_dict': model.state_dict(),
                        'val_miou': val_miou}, model_path)
            print(f'  [Epoch {epoch+1}] New best model saved (val_mIoU={val_miou:.4f})')

        # --- PRINT every 5 epochs ---
        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}]')
            print(f'  Train - Loss: {train_loss:.4f}, F1: {train_metrics[0]:.4f}, mIoU: {train_metrics[1]:.4f}')
            print(f'  Val   - Loss: {val_loss:.4f}, F1: {val_metrics[0]:.4f}, mIoU: {val_metrics[1]:.4f}')

        # --- EARLY STOPPING ---
        early_stopping(val_loss, model)
        if early_stopping.stop:
            print(f'\n  Early stopping at epoch {epoch+1}')
            break

    early_stopping.restore_best_weights(model)

    # reload best model for testing consistency
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # --- TEST ---
    test_loss, test_metrics = 0, [0]*4
    with torch.no_grad():
        for images, masks in test_loader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            loss = criterion(outputs, masks)
            test_loss += loss.item()
            metrics = get_metrics(outputs, masks)
            test_metrics = [x + y for x, y in zip(test_metrics, metrics)]
    test_loss /= len(test_loader)
    test_metrics = [x / len(test_loader) for x in test_metrics]

    names = ['F1', 'mIoU', 'MCC', 'HAF']
    print(f'\n{"="*70}')
    print(f'RESULTS - {pct_str} Dataset (DeepLabV3+ ResNet50)')
    print(f'{"="*70}')
    print(f"\n{'Metric':<12} {'Train':>10} {'Val':>10} {'Test':>10}")
    print('-' * 45)
    for i, name in enumerate(names):
        print(f'{name:<12} {train_metrics[i]:>10.4f} {val_metrics[i]:>10.4f} {test_metrics[i]:>10.4f}')
    print('-' * 45)
    print(f"{'Loss':<12} {train_loss:>10.4f} {val_loss:>10.4f} {test_loss:>10.4f}")

    test_results = {
        'test_loss': test_loss,
        'test_f1':   test_metrics[0],
        'test_miou': test_metrics[1],
        'test_mcc':  test_metrics[2],
        'test_haf':  test_metrics[3],
    }

    # Save history and results to JSON
    with open(history_path, 'w') as f:
        _json.dump(history, f)
    with open(results_path, 'w') as f:
        _json.dump(test_results, f)

    print(f'\n  Guardado en Drive:')
    print(f'    Modelo    : deeplabv3plus_{pct_tag}.pth')
    print(f'    Historial : deeplabv3plus_history_{pct_tag}.json')
    print(f'    Resultados: deeplabv3plus_results_{pct_tag}.json')

    return history, test_results, model

# %%
train_25, val_25, test_25 = create_data_splits(
    images_path, masks_path, train_transform, val_transform, data_percentage=0.25)

train_loader_25 = DataLoader(train_25, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader_25   = DataLoader(val_25,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader_25  = DataLoader(test_25,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

history_25, test_results_25, model_25 = train_model(
    train_loader_25, val_loader_25, test_loader_25,
    data_percentage=0.25, num_epochs=NUM_EPOCHS)
# Out:
# Using 25% of dataset:
#   Total images : 24215
#   Used images  : 6053
#   Train        : 4237
#   Val          : 907
#   Test         : 909
#
# ======================================================================
# TRAINING DeepLabV3+ (ResNet50) WITH 25% OF DATASET
# ======================================================================
#
#   [Epoch 1] New best model saved (val_mIoU=0.4477)
# Epoch [1/50]
#   Train - Loss: 0.6339, F1: 0.4346, mIoU: 0.2886
#   Val   - Loss: 0.4076, F1: 0.6158, mIoU: 0.4477
#   [Epoch 3] New best model saved (val_mIoU=0.4618)
#   [Epoch 4] New best model saved (val_mIoU=0.5075)
#   [Epoch 5] New best model saved (val_mIoU=0.5119)
# Epoch [5/50]
#   Train - Loss: 0.3352, F1: 0.6687, mIoU: 0.5047
#   Val   - Loss: 0.3283, F1: 0.6745, mIoU: 0.5119
#   [Epoch 6] New best model saved (val_mIoU=0.5259)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.3151)
#   [Epoch 8] New best model saved (val_mIoU=0.5426)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.3002)
#   [Epoch 10] New best model saved (val_mIoU=0.5441)
# Epoch [10/50]
#   Train - Loss: 0.2871, F1: 0.7148, mIoU: 0.5581
#   Val   - Loss: 0.2984, F1: 0.7028, mIoU: 0.5441
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2984)
#   [Epoch 12] New best model saved (val_mIoU=0.5566)
#   [Epoch 13] New best model saved (val_mIoU=0.5597)
#   [Epoch 14] New best model saved (val_mIoU=0.5631)
#   [Epoch 15] New best model saved (val_mIoU=0.5672)
# Epoch [15/50]
#   Train - Loss: 0.2627, F1: 0.7385, mIoU: 0.5871
#   Val   - Loss: 0.2790, F1: 0.7219, mIoU: 0.5672
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2790)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2790)
#   [Epoch 18] New best model saved (val_mIoU=0.5739)
#   [Epoch 19] New best model saved (val_mIoU=0.5764)
#   [Epoch 20] New best model saved (val_mIoU=0.5782)
# Epoch [20/50]
#   Train - Loss: 0.2476, F1: 0.7533, mIoU: 0.6057
#   Val   - Loss: 0.2697, F1: 0.7310, mIoU: 0.5782
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2697)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2697)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.2697)
#   [Epoch 24] New best model saved (val_mIoU=0.5788)
#   [Epoch 25] New best model saved (val_mIoU=0.5831)
# Epoch [25/50]
#   Train - Loss: 0.2342, F1: 0.7665, mIoU: 0.6226
#   Val   - Loss: 0.2658, F1: 0.7348, mIoU: 0.5831
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2658)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2658)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.2658)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.2658)
#   [Epoch 30] New best model saved (val_mIoU=0.5835)
# Epoch [30/50]
#   Train - Loss: 0.2254, F1: 0.7753, mIoU: 0.6342
#   Val   - Loss: 0.2653, F1: 0.7352, mIoU: 0.5835
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2653)
#   [Epoch 32] New best model saved (val_mIoU=0.5855)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2637)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2637)
# Epoch [35/50]
#   Train - Loss: 0.2185, F1: 0.7820, mIoU: 0.6431
#   Val   - Loss: 0.2646, F1: 0.7357, mIoU: 0.5841
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.2637)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.2637)
#   [Epoch 37] New best model saved (val_mIoU=0.5937)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2568)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2568)
# Epoch [40/50]
#   Train - Loss: 0.2114, F1: 0.7890, mIoU: 0.6526
#   Val   - Loss: 0.2589, F1: 0.7415, mIoU: 0.5917
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.2568)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.2568)
#   [Epoch 42] New best model saved (val_mIoU=0.5948)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2561)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2561)
#   [Epoch 45] New best model saved (val_mIoU=0.5964)
# Epoch [45/50]
#   Train - Loss: 0.2066, F1: 0.7938, mIoU: 0.6592
#   Val   - Loss: 0.2548, F1: 0.7455, mIoU: 0.5964
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.2548)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.2548)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.2548)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.2548)
# Epoch [50/50]
#   Train - Loss: 0.2035, F1: 0.7969, mIoU: 0.6633
#   Val   - Loss: 0.2655, F1: 0.7349, mIoU: 0.5832
#   EarlyStopping: no improvement for 5/10 epochs (best val_loss=0.2548)
#   Best weights restored (val_loss=0.2548)
#
# ======================================================================
# RESULTS - 25% Dataset (DeepLabV3+ ResNet50)
# ======================================================================
#
# Metric            Train        Val       Test
# ---------------------------------------------
# F1               0.7969     0.7349     0.7362
# mIoU             0.6633     0.5832     0.5854
# MCC              0.7923     0.7311     0.7321
# HAF              0.6633     0.5832     0.5854
# ---------------------------------------------
# Loss             0.2035     0.2655     0.2642
#
#   Guardado en Drive:
#     Modelo    : deeplabv3plus_25.pth
#     Historial : deeplabv3plus_history_25.json
#     Resultados: deeplabv3plus_results_25.json

# %%
train_50, val_50, test_50 = create_data_splits(
    images_path, masks_path, train_transform, val_transform, data_percentage=0.50)

train_loader_50 = DataLoader(train_50, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader_50   = DataLoader(val_50,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader_50  = DataLoader(test_50,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

history_50, test_results_50, model_50 = train_model(
    train_loader_50, val_loader_50, test_loader_50,
    data_percentage=0.50, num_epochs=NUM_EPOCHS)
# Out:
# Using 50% of dataset:
#   Total images : 500
#   Used images  : 250
#   Train        : 175
#   Val          : 37
#   Test         : 38
#
# ======================================================================
# TRAINING DeepLabV3+ (ResNet50) WITH 50% OF DATASET
# ======================================================================
#
#   [Epoch 1] Nuevo mejor modelo guardado (val_mIoU=0.5583)
# Epoch [1/50]
#   Train - Loss: 0.5756, F1: 0.5632, mIoU: 0.4066
#   Val   - Loss: 0.6113, F1: 0.7163, mIoU: 0.5583
#   [Epoch 2] Nuevo mejor modelo guardado (val_mIoU=0.5833)
#   [Epoch 3] Nuevo mejor modelo guardado (val_mIoU=0.7129)
#   [Epoch 4] Nuevo mejor modelo guardado (val_mIoU=0.7472)
#   [Epoch 5] Nuevo mejor modelo guardado (val_mIoU=0.7710)
# Epoch [5/50]
#   Train - Loss: 0.2666, F1: 0.8342, mIoU: 0.7226
#   Val   - Loss: 0.2211, F1: 0.8704, mIoU: 0.7710
#   [Epoch 6] Nuevo mejor modelo guardado (val_mIoU=0.7877)
#   [Epoch 7] Nuevo mejor modelo guardado (val_mIoU=0.8260)
#   [Epoch 10] Nuevo mejor modelo guardado (val_mIoU=0.8329)
# Epoch [10/50]
#   Train - Loss: 0.1597, F1: 0.9052, mIoU: 0.8275
#   Val   - Loss: 0.1436, F1: 0.9087, mIoU: 0.8329
#   [Epoch 11] Nuevo mejor modelo guardado (val_mIoU=0.8407)
#   [Epoch 12] Nuevo mejor modelo guardado (val_mIoU=0.8437)
#   [Epoch 13] Nuevo mejor modelo guardado (val_mIoU=0.8452)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.1202)
# Epoch [15/50]
#   Train - Loss: 0.1376, F1: 0.9024, mIoU: 0.8241
#   Val   - Loss: 0.1256, F1: 0.9027, mIoU: 0.8234
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.1202)
#   [Epoch 16] Nuevo mejor modelo guardado (val_mIoU=0.8562)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.1046)
#   [Epoch 19] Nuevo mejor modelo guardado (val_mIoU=0.8621)
#   [Epoch 20] Nuevo mejor modelo guardado (val_mIoU=0.8662)
# Epoch [20/50]
#   Train - Loss: 0.0995, F1: 0.9272, mIoU: 0.8649
#   Val   - Loss: 0.0911, F1: 0.9281, mIoU: 0.8662
#   [Epoch 21] Nuevo mejor modelo guardado (val_mIoU=0.8703)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0897)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0897)
# Epoch [25/50]
#   Train - Loss: 0.0860, F1: 0.9336, mIoU: 0.8757
#   Val   - Loss: 0.0918, F1: 0.9215, mIoU: 0.8555
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0858)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0858)
#   [Epoch 28] Nuevo mejor modelo guardado (val_mIoU=0.8710)
#   [Epoch 29] Nuevo mejor modelo guardado (val_mIoU=0.8711)
# Epoch [30/50]
#   Train - Loss: 0.0778, F1: 0.9386, mIoU: 0.8846
#   Val   - Loss: 0.0845, F1: 0.9267, mIoU: 0.8641
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0802)
#   [Epoch 31] Nuevo mejor modelo guardado (val_mIoU=0.8771)
#   [Epoch 32] Nuevo mejor modelo guardado (val_mIoU=0.8778)
#   [Epoch 33] Nuevo mejor modelo guardado (val_mIoU=0.8789)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0743)
# Epoch [35/50]
#   Train - Loss: 0.0691, F1: 0.9441, mIoU: 0.8942
#   Val   - Loss: 0.0771, F1: 0.9321, mIoU: 0.8732
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 5/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 6/10 epochs (best val_loss=0.0743)
# Epoch [40/50]
#   Train - Loss: 0.0774, F1: 0.9336, mIoU: 0.8761
#   Val   - Loss: 0.0750, F1: 0.9333, mIoU: 0.8751
#   EarlyStopping: no improvement for 7/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 8/10 epochs (best val_loss=0.0743)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0731)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0731)
#   [Epoch 45] Nuevo mejor modelo guardado (val_mIoU=0.8808)
# Epoch [45/50]
#   Train - Loss: 0.0653, F1: 0.9439, mIoU: 0.8940
#   Val   - Loss: 0.0699, F1: 0.9365, mIoU: 0.8808
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0699)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0699)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0699)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.0699)
# Epoch [50/50]
#   Train - Loss: 0.0626, F1: 0.9460, mIoU: 0.8976
#   Val   - Loss: 0.0707, F1: 0.9346, mIoU: 0.8774
#   EarlyStopping: no improvement for 5/10 epochs (best val_loss=0.0699)
#   Best weights restored (val_loss=0.0699)
#
# ======================================================================
# RESULTS - 50% Dataset (DeepLabV3+ ResNet50)
# ======================================================================
#
# Metric            Train        Val       Test
# ---------------------------------------------
# F1               0.9460     0.9346     0.9290
# mIoU             0.8976     0.8774     0.8676
# MCC              0.9343     0.9187     0.9126
# HAF              0.8976     0.8774     0.8676
# ---------------------------------------------
# Loss             0.0626     0.0707     0.0780
#
#   Guardado en Drive:
#     Modelo    : deeplabv3plus_50.pth
#     Historial : deeplabv3plus_history_50.json
#     Resultados: deeplabv3plus_results_50.json

# %%
train_100, val_100, test_100 = create_data_splits(
    images_path, masks_path, train_transform, val_transform, data_percentage=1.0)

train_loader_100 = DataLoader(train_100, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader_100   = DataLoader(val_100,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader_100  = DataLoader(test_100,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

history_100, test_results_100, model_100 = train_model(
    train_loader_100, val_loader_100, test_loader_100,
    data_percentage=1.0, num_epochs=NUM_EPOCHS)
# Out:
# Using 100% of dataset:
#   Total images : 500
#   Used images  : 500
#   Train        : 350
#   Val          : 75
#   Test         : 75
#
# ======================================================================
# TRAINING DeepLabV3+ (ResNet50) WITH 100% OF DATASET
# ======================================================================
#
#   [Epoch 1] Nuevo mejor modelo guardado (val_mIoU=0.6946)
# Epoch [1/50]
#   Train - Loss: 0.4649, F1: 0.6695, mIoU: 0.5143
#   Val   - Loss: 0.3102, F1: 0.8194, mIoU: 0.6946
#   [Epoch 2] Nuevo mejor modelo guardado (val_mIoU=0.7814)
#   [Epoch 3] Nuevo mejor modelo guardado (val_mIoU=0.8256)
#   [Epoch 4] Nuevo mejor modelo guardado (val_mIoU=0.8460)
#   [Epoch 5] Nuevo mejor modelo guardado (val_mIoU=0.8590)
# Epoch [5/50]
#   Train - Loss: 0.1560, F1: 0.8983, mIoU: 0.8182
#   Val   - Loss: 0.1100, F1: 0.9241, mIoU: 0.8590
#   [Epoch 6] Nuevo mejor modelo guardado (val_mIoU=0.8647)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0963)
#   [Epoch 8] Nuevo mejor modelo guardado (val_mIoU=0.8660)
#   [Epoch 9] Nuevo mejor modelo guardado (val_mIoU=0.8712)
#   [Epoch 10] Nuevo mejor modelo guardado (val_mIoU=0.8751)
# Epoch [10/50]
#   Train - Loss: 0.0954, F1: 0.9268, mIoU: 0.8638
#   Val   - Loss: 0.0797, F1: 0.9334, mIoU: 0.8751
#   [Epoch 11] Nuevo mejor modelo guardado (val_mIoU=0.8759)
#   [Epoch 12] Nuevo mejor modelo guardado (val_mIoU=0.8761)
#   [Epoch 13] Nuevo mejor modelo guardado (val_mIoU=0.8791)
#   [Epoch 15] Nuevo mejor modelo guardado (val_mIoU=0.8799)
# Epoch [15/50]
#   Train - Loss: 0.0806, F1: 0.9328, mIoU: 0.8744
#   Val   - Loss: 0.0716, F1: 0.9361, mIoU: 0.8799
#   [Epoch 16] Nuevo mejor modelo guardado (val_mIoU=0.8808)
#   [Epoch 17] Nuevo mejor modelo guardado (val_mIoU=0.8816)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0697)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0697)
# Epoch [20/50]
#   Train - Loss: 0.0685, F1: 0.9404, mIoU: 0.8876
#   Val   - Loss: 0.0694, F1: 0.9364, mIoU: 0.8805
#   [Epoch 22] Nuevo mejor modelo guardado (val_mIoU=0.8823)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0676)
#   [Epoch 24] Nuevo mejor modelo guardado (val_mIoU=0.8834)
#   [Epoch 25] Nuevo mejor modelo guardado (val_mIoU=0.8846)
# Epoch [25/50]
#   Train - Loss: 0.0651, F1: 0.9423, mIoU: 0.8911
#   Val   - Loss: 0.0654, F1: 0.9387, mIoU: 0.8846
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0654)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0654)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0654)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.0654)
# Epoch [30/50]
#   Train - Loss: 0.0616, F1: 0.9441, mIoU: 0.8943
#   Val   - Loss: 0.0680, F1: 0.9352, mIoU: 0.8784
#   EarlyStopping: no improvement for 5/10 epochs (best val_loss=0.0654)
#   [Epoch 31] Nuevo mejor modelo guardado (val_mIoU=0.8848)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0645)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0645)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0645)
#   [Epoch 35] Nuevo mejor modelo guardado (val_mIoU=0.8849)
# Epoch [35/50]
#   Train - Loss: 0.0594, F1: 0.9452, mIoU: 0.8963
#   Val   - Loss: 0.0641, F1: 0.9389, mIoU: 0.8849
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0641)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0641)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0641)
# Epoch [40/50]
#   Train - Loss: 0.0547, F1: 0.9493, mIoU: 0.9036
#   Val   - Loss: 0.0662, F1: 0.9362, mIoU: 0.8802
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0638)
#   [Epoch 41] Nuevo mejor modelo guardado (val_mIoU=0.8851)
#   [Epoch 42] Nuevo mejor modelo guardado (val_mIoU=0.8853)
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0632)
#   [Epoch 44] Nuevo mejor modelo guardado (val_mIoU=0.8864)
# Epoch [45/50]
#   Train - Loss: 0.0613, F1: 0.9424, mIoU: 0.8916
#   Val   - Loss: 0.0694, F1: 0.9328, mIoU: 0.8741
#   EarlyStopping: no improvement for 1/10 epochs (best val_loss=0.0624)
#   EarlyStopping: no improvement for 2/10 epochs (best val_loss=0.0624)
#   EarlyStopping: no improvement for 3/10 epochs (best val_loss=0.0624)
#   EarlyStopping: no improvement for 4/10 epochs (best val_loss=0.0624)
#   EarlyStopping: no improvement for 5/10 epochs (best val_loss=0.0624)
# Epoch [50/50]
#   Train - Loss: 0.0539, F1: 0.9493, mIoU: 0.9037
#   Val   - Loss: 0.0633, F1: 0.9385, mIoU: 0.8842
#   EarlyStopping: no improvement for 6/10 epochs (best val_loss=0.0624)
#   Best weights restored (val_loss=0.0624)
#
# ======================================================================
# RESULTS - 100% Dataset (DeepLabV3+ ResNet50)
# ======================================================================
#
# Metric            Train        Val       Test
# ---------------------------------------------
# F1               0.9493     0.9385     0.9410
# mIoU             0.9037     0.8842     0.8886
# MCC              0.9374     0.9186     0.9251
# HAF              0.9037     0.8842     0.8886
# ---------------------------------------------
# Loss             0.0539     0.0633     0.0617
#
#   Guardado en Drive:
#     Modelo    : deeplabv3plus_100.pth
#     Historial : deeplabv3plus_history_100.json
#     Resultados: deeplabv3plus_results_100.json

# %%
all_test_results = {'25%': test_results_25, '50%': test_results_50, '100%': test_results_100}

print('=' * 80)
print('SUMMARY: TEST SET RESULTS FOR DIFFERENT DATASET SIZES')
print('=' * 80)
print(f"{'Dataset':<12} {'Loss':<10} {'F1':<10} {'mIoU':<10} {'MCC':<10} {'HAF':<10}")
print('-' * 80)
for pct in ['25%', '50%', '100%']:
    r = all_test_results[pct]
    print(f"{pct:<12} {r['test_loss']:<10.4f} {r['test_f1']:<10.4f} "
          f"{r['test_miou']:<10.4f} {r['test_mcc']:<10.4f} {r['test_haf']:<10.4f}")
print('=' * 80)
# Out:
# ================================================================================
# SUMMARY: TEST SET RESULTS FOR DIFFERENT DATASET SIZES
# ================================================================================
# Dataset      Loss       F1         mIoU       MCC        HAF
# --------------------------------------------------------------------------------
# 25%          0.0938     0.9215     0.8550     0.9063     0.8550
# 50%          0.0780     0.9290     0.8676     0.9126     0.8676
# 100%         0.0617     0.9410     0.8886     0.9251     0.8886
# ================================================================================

# %%
import matplotlib.pyplot as plt

all_histories = {'25%': history_25, '50%': history_50, '100%': history_100}
titles = ['Loss', 'F1 Score', 'mIoU', 'MCC']
keys   = [('train_loss','val_loss'), ('train_f1','val_f1'),
          ('train_miou','val_miou'), ('train_mcc','val_mcc')]
colors = {'25%':'blue', '50%':'orange', '100%':'green'}

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for ax, title, (tk, vk) in zip(axes, titles, keys):
    for pct, hist in all_histories.items():
        c = colors[pct]
        ax.plot(hist[tk], color=c, linestyle='-',  label=f'{pct} train')
        ax.plot(hist[vk], color=c, linestyle='--', label=f'{pct} val')
    ax.set_title(title)
    ax.set_xlabel('Epoch')
    ax.legend(fontsize=7)
    ax.grid(True)

plt.suptitle('DeepLabV3+ + ResNet50 — Training curves (25% / 50% / 100%)', fontsize=13)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import random

model_100.eval()

# Sample random indices from the test set (different each time)
num_imgs = 8
test_dataset = test_loader_100.dataset
random_indices = random.sample(range(len(test_dataset)), num_imgs)

# Build batch of images and masks for the sampled indices
images_list, masks_list = [], []
for idx in random_indices:
    img, mask = test_dataset[idx]
    images_list.append(img)
    masks_list.append(mask)

images = torch.stack(images_list).to(device)
masks  = torch.stack(masks_list)

with torch.no_grad():
    outputs = model_100(images)
    preds = torch.sigmoid(outputs)
    preds = (preds > 0.5).float()

# Denormalize images for visualization
mean = torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
std  = torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)

fig, axes = plt.subplots(num_imgs, 3, figsize=(12, num_imgs * 4))

for i in range(num_imgs):
    img       = images[i].cpu() * std + mean
    img       = img.permute(1, 2, 0).clamp(0, 1)
    mask_real = masks[i].cpu().squeeze()
    mask_pred = preds[i].cpu().squeeze()

    axes[i, 0].imshow(img)
    axes[i, 0].set_title(f"Original image (idx {random_indices[i]})")
    axes[i, 0].axis("off")

    axes[i, 1].imshow(mask_real, cmap="gray")
    axes[i, 1].set_title("Real mask")
    axes[i, 1].axis("off")

    axes[i, 2].imshow(mask_pred, cmap="gray")
    axes[i, 2].set_title("Predicted mask")
    axes[i, 2].axis("off")

plt.tight_layout()
plt.show()
